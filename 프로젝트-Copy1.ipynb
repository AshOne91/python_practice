# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import requests

url = 'https://stat.molit.go.kr/portal/cate/statView.do?hRsId=58&hFormId=5498&hSelectId=5559&hPoint=00&hAppr=1&hDivEng=&oFileName=&rFileName=&midpath=&sFormId=5498&sStart=201303&sEnd=202502&sStyleNum=1&settingRadio=xlsx/robots.txt'
driver = webdriver.Chrome()
#chrome 브라우저열기
driver.get(url)
time.sleep(1)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
th_list = soup.select('#sheet01-table > tbody > tr:nth-child(1) > td:nth-child(2) > div > table > tbody > tr:nth-child(1) > th')

# span_list = []
# for th in th_list :
#     spans = th.find_all("span")
#     for span in spans:
#         print(span.text.strip())  # 텍스트 출력
#         span_list.append(span.text.strip())
        
# del span_list[-1]
# span_list[0:3] = ["날짜", "시도명", "시군구"]
# print(span_list)

date = soup.select('#sheet01-table > tbody > tr:nth-child(2) > td:nth-child(1) > div > div.GMPageFirst > table > tbody > tr:nth-child(2) > td.GMClassReadOnly.GMWrap0.GMText.GMCell.IBSheetFont0.HideCol0C1')

tbody = soup.select('#sheet01-table > tbody')

print(tbody)

td_elements = soup.select('#sheet01-table > tbody > tr > td.GMClassReadOnly')
print(td_elements)

#districts = [td.get_text(strip=True) for td in td_elements]
#print(districts)

# tr_list = soup.select('#sheet01-table > tbody > tr:nth-child(2) > td:nth-child(1) > div > div.GMPageFirst > table > tbody > tr.GMDataRow.GMClassFocused')
# #tr시군구 값 나오는 부분
# #sheet01-table > tbody > tr:nth-child(2) > td:nth-child(1) > div > div.GMPageFirst > table > tbody > tr:nth-child(i+3)
# #sheet01-table > tbody > tr:nth-child(2) > td:nth-child(1) > div > div.GMPageFirst > table > tbody > tr:nth-child(4)

# for _ in ien():
#     tr_list = soup.select('#sheet01-table > tbody > tr:nth-child(2) > td:nth-child(1) > div > div.GMPageFirst > table > tbody > tr:nth-child(i+3)')
#     td = tr.find('tr', onmousemove=True) 
#     print(td)


driver.quit()
# Out:
# [<tbody><tr><td style="overflow:hidden;"><div class="GMHeadLeft" style="overflow: hidden; width: 149px;"><table cellpadding="0" cellspacing="0" class="GMSection"><tbody><tr><td scope="col" style="width:0px;"></td><th scope="col" style="height: 0px; width: 30px; font-size: 0px !important; line-height: 0px !important; visibility: hidden !important;"><span style="font-size:0px!important;line-height:0px!important;visibility:hidden!important;">월(Monthly) 월(Monthly)</span></th><th scope="col" style="height:0px;width:20px;"></th><th scope="col" style="height:0px;width:30px;font-size:0px!important;line-height:0px!important;visibility:hidden!important;"><span style="font-size:0px!important;line-height:0px!important;visibility:hidden!important;">시도명 시도명</span></th><th scope="col" style="height:0px;width:20px;"></th><th scope="col" style="height:0px;width:30px;font-size:0px!important;line-height:0px!important;visibility:hidden!important;"><span style="font-size:0px!important;line-height:0px!imp
# ...

# %%
#sheet01-table > tbody > tr:nth-child(2) > td:nth-child(1) > div > div.GMPageFirst > table > tbody > tr.GMDataRow.GMClassFocused > td.GMClassReadOnly.GMWrap0.GMText.GMCell.IBSheetFont0.HideCol0C3
#sheet01-table > tbody > tr:nth-child(2) > td:nth-child(1) > div > div.GMPageFirst > table > tbody > tr:nth-child(3) > td.GMClassReadOnly.GMWrap0.GMText.GMCell.IBSheetFont0.HideCol0C3
#sheet01-table > tbody > tr:nth-child(2) > td:nth-child(1) > div > div.GMPageFirst > table > tbody > tr:nth-child(4) > td.GMClassReadOnly.GMWrap0.GMText.GMCell.IBSheetFont0.HideCol0C3
